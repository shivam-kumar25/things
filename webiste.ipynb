# %%
from IPython.display import IFrame

# This site allows embedding, so it will work perfectly
IFrame(src="https://scikit-learn.org/stable/", width="100%", height=500)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://scikit-learn.org/stable/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame

# Display a webpage (note: many sites block this feature)
IFrame(src="https://python.org", width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="https://python.org"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
