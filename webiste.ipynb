# %%
from IPython.display import IFrame

# This site allows embedding, so it will work perfectly
IFrame(src="https://scikit-learn.org/stable/", width="100%", height=500)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://scikit-learn.org/stable/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame

# Display a webpage (note: many sites block this feature)
IFrame(src="https://tympanus.net/codrops/", width=700, height=400)


# https://tympanus.net/codrops/ 
# good website for web design and development tutorials, inspiration, and resources. It features a variety of articles, demos, and code snippets that can help developers enhance their skills and stay updated with the latest trends in web design.
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="https://tympanus.net/codrops/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# https://www.nngroup.com/

IFrame(src="https://www.nngroup.com/", width="100%", height=500)

# good website for web design and development tutorials, inspiration, and resources. It features a variety of articles, demos, and code snippets that can help developers enhance their skills and stay updated with the latest trends in web design.
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://www.nngroup.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# https://dribbble.com/

IFrame(src="https://dribbble.com/", width="100%", height=500)

# good website for web design and development inspiration, and resources. It features a variety of articles, demos, and code snippets that can help developers enhance their skills and stay updated with the latest trends in web design.
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://dribbble.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# https://peerlist.io/

IFrame(src="https://peerlist.io/", width="100%", height=500)

# good website for getting to know trends and also job search.
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://peerlist.io/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# https://www.pinterest.com/

IFrame(src="https://www.pinterest.com/", width="100%", height=500)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://www.pinterest.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
