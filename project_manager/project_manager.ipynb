# %% [markdown]
# uv python : discussed in : python git hub repository
#
#
#
#
# [uv](https://docs.astral.sh/uv/) is an extremely fast, all-in-one Python package and project manager written in Rust by [Astral](https://astral.sh/blog/uv).
