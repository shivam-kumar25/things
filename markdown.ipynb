# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
#
# # Divider
# ---
#
# # Mathematical equations
#
# $$ y = f(x) = w^x + b  $$
#
# ---
#
# $$ y = w_1 x_1 + w_2 x_2 + w_3 x_3 + b  $$
#
# ---
#
# $$ y = w_x - b $$
#
# ---
#
# # Matrix Representation
#
#
# $$
# \begin{bmatrix} y_1 \\ y_2 \\ y_3 \end{bmatrix} = \begin{bmatrix} w_{11} & w_{12} & w_{13} \\ w_{21} & w_{22} & w_{23} \\ w_{31} & w_{32} & w_{33} \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \\ x_3 \end{bmatrix} + \begin{bmatrix} b_1 \\ b_2 \\ b_3 \end{bmatrix}
# $$
#
# # fractions
# $$
# \frac{1}{2}
# $$

# %% [markdown]
# # Symbols
#
# $$
# \in : Element of
# $$
#
# $$
# \notin : Not an element of
# $$
#
# $$
# \subset : Subset of
# $$
#
# $$
# \cup : Union
# $$
#
# $$
# \cap : Intersection
# $$
#
# $$
# \pi : Pi
# $$

# %% [markdown]
# # Lists
#
# ## Unordered list
# - Item 1
# - Item 2
# - Item 3
#
# ## Ordered list
# 1. First item
# 2. Second item
# 3. Third item
#
#
# ## Nested list
# - Item 1
#   - Subitem 1.1
#   - Subitem 1.2
# - Item 2
#   1. Subitem 2.1
#   2. Subitem 2.2
# - Item 3
#   - Subitem 3.1
#   - Subitem 3.2
#
#
# ## Task list
# - [x] Task 1
# - [X] Task 2
# - [ ] Task 3
#
# ---

# %% [markdown]
# # Links
# [Link Text](Actual URL)
#
# [Google](https://www.google.com)
# [GitHub](https://www.github.com)
#
# ---
#
# # Images
# ![Alt Text](Image URL)
# ![GitHub Logo](https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png)
#
# ---

# %% [markdown]
# # Code blocks
#
# ## Python block with syntax highlighting
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# ```
#
# ## JavaScript block with syntax highlighting
# ```javascript
# function greet(name) {
#     return `Hello, ${name}!`;
# }
# ```
#
# ## HTML block with syntax highlighting
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Sample HTML</title>
# </head>
# <body>
#     <h1>Hello, World!</h1>
# </body></html>
# ```
#
#
# ## Bash block with syntax highlighting
# ```bash
# echo "Hello, World!"
# ```
#
# ## SQL block with syntax highlighting
# ```sql
# SELECT * FROM users WHERE age > 30;
# ```
#
# ## Java block with syntax highlighting
# ```java
# public class HelloWorld {
#     public static void main(String[] args) {
#         System.out.println("Hello, World!");
#     }
# }
# ```
#
# ## C block with syntax highlighting
# ```c
# #include <stdio.h>
# int main() {
#     printf("Hello, World!\n");
#     return 0;
# }
# ```

# %% [markdown]
# # Table
#
# | Name  | Age | City       |
# |-------|-----|------------|
# | Alice | 30  | New York   |
# | Bob   | 25  | Los Angeles|
