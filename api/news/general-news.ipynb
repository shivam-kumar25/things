# %% [markdown]
# #

# %% [markdown]
# ## Gnews
#
#
# link : https://gnews.io/
#
# Simple News API for Developers
# Search articles from over 80,000 sources worldwide. Get real-time news and up to 6 years of historical data in JSON format. Start for free.

# %% [markdown]
# ##
#
# link: https://newsapi.org/
#
# Search worldwide news with code
# Locate articles and breaking news headlines from news sources and blogs across the web with our JSON API

# %% [markdown]
# link: https://open-platform.theguardian.com/

# %% [markdown]
# link: https://developer.nytimes.com/
#
#
# The New York Times Developer Network
# All the APIs Fit to Post

# %% [markdown]
# ##
#
# link: https://currentsapi.services/en
#
# Curate and Analyze Online News Effortlessly
# Currents News API provides a comprehensive solution for curating global news and delivering it in a parseable JSON format. Our affordable news API is 500x cheaper than competitors.

# %% [markdown]
# ##
#
# link: https://newsdata.io/
#
#
# Best News API To Search, Collect
# And Track Worldwide News
# Get live breaking news or search historical news data for the past 8 years (since January 2018) from 95868+ sources using NewsData.io API. Collect the data in JSON or Excel Formats.

# %% [markdown]
# ##
#
# link: https://mediastack.com/
#
#
# Free, Simple REST API for
# Live News & Blog Articles
# Scalable JSON API delivering worldwide news,
# headlines and blog articles in real-time
# Supporting 7,500+ News Sources
#
# 100 Free Requests per month
# Instant access to live news data from 50+ countries in multiple languages

# %% [markdown]
# link: https://worldnewsapi.com/
#
# The World News API gives you access to thousands of news sources in over 86 languages from over 210 countries in real time. News are semantically tagged allowing for semantic news search like never before.

# %% [markdown]
# link: https://www.perigon.io/home
